# %% [markdown]
# # Birge-Sponer plots in vibrational spectroscopy

# %%
import Helper
# %pylab inline
import seaborn as sbn
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
Helper.populate_form()
# Out:
# Box(children=(Box(children=(Label(value='Vibrations'), Textarea(value='')), layout=Layout(display='flex', flex…

# %%
form
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9e6c0795b08e> in <module>
# ----> 1 form
#
# NameError: name 'form' is not defined

# %%
vibrations = form.children[0].children[1].value
levels = form.children[1].children[1].value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b1e9ca60a29a> in <module>
# ----> 1 vibrations = form.children[0].children[1].value
#       2 levels = form.children[1].children[1].value
#
# NameError: name 'form' is not defined

# %%
vibrations = '12399.8, 9826.48,7149.04,4367.50,1481.86'
levels = '0.5,1.5,2.5,3.5,4.5'

# %%
Helper.plot_birge_sponer(vibrations,levels)
# Out:
# [12399.8, 9826.48, 7149.04, 4367.5, 1481.86]

# %%
Helper.plot_extrapolated_birge_sponer(vibrations,levels)
# Out:
# [12399.8, 9826.48, 7149.04, 4367.5, 1481.86]

# %%
Helper.compute_area_under_graph(vibrations,levels)
# Out:
# [12399.8, 9826.48, 7149.04, 4367.5, 1481.86]

# %%
plt.
# Out:
#   File "<ipython-input-10-efb1a9b93a17>", line 1
#     plt.
#         ^
# SyntaxError: invalid syntax

# %%
do_plot = widgets.Button(
    description='Birge-Sponer Plot',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    #icon='check' # (FontAwesome names without the `fa-` prefix)
)
display(do_plot)
if do_plot.disabled==False:
    plt.plot(levels,transitions)
# Out:
# Button(description='Birge-Sponer Plot', style=ButtonStyle(), tooltip='Click me')

# %% [markdown]
# ## 1. Molecules move

# %%
transitions = np.array([12399.8, 9826.48,7149.04,4367.50,1481.86])
levels = np.array([0.5,1.5,2.5,3.5,4.5])

# %%
plt.plot(levels,transitions)

# %%
from scipy.interpolate import InterpolatedUnivariateSpline
from scipy import interpolate

# %%
f = interpolate.interp1d(levels, transitions, fill_value='extrapolate')

# %%
f(5.0135)
# Out:
# array(0.08386)

# %%
area = np.trapz(transitions, dx=5)
print("area =", area)
# Out:
# area = 141419.25

# %% [markdown]
# ## 2. How can we quantify the movement

# %%
from scipy.stats import linregress
fit = linregress(levels, transitions)

# %%
x_max = -fit[1]/fit[0]
new_x = np.linspace(0,x_max, 20)
new_y = fit[0]*new_x+fit[1]

# %% [markdown]
# ## 3. How can we measure the movement

# %%
plt.plot(new_x,new_y)

# %%
A = 0.5*max(new_y)*max(new_x)

# %%
A
# Out:
# 35233.64482539955

# %%
import scipy.constants as con

# %%
con.c*(A)*con.h*con.Avogadro*100
# Out:
# 421487.9925396196

# %%
con.c
# Out:
# 299792458.0
